# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../stats_case_study/data/cars.csv')
print(df.head())
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8         307.0      130.0  3504.0          12.0     70
# 1  15.0          8         350.0      165.0  3693.0          11.5     70
# 2  18.0          8         318.0      150.0  3436.0          11.0     70
# 3  16.0          8         304.0      150.0  3433.0          12.0     70
# 4  17.0          8         302.0      140.0  3449.0          10.5     70
#
#    origin                   car_name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.T
# Out:
#                                     0                  1    \
# mpg                                18.0               15.0
# cylinders                             8                  8
# displacement                      307.0              350.0
# horsepower                        130.0              165.0
# weight                           3504.0             3693.0
# acceleration                       12.0               11.5
# model                                70                 70
# origin                                1                  1
# car_name      chevrolet chevelle malibu  buick skylark 320
#
#                              2              3            4    \
# mpg                         18.0           16.0         17.0
# cylinders                      8              8            8
# displacement               318.0          304.0        302.0
# horsepower                 150.0          150.0        140.0
# weight                    3436.0         3433.0       3449.0
# ...

# %%
df_dupe = df[df.duplicated()]
df_dupe
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, model, origin, car_name]
# Index: []

# %%
df.shape
# Out:
# (398, 9)

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model           0
# origin          0
# car_name        0
# dtype: int64

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#             model      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight          float64
# acceleration    float64
# model             int64
# origin            int64
# car_name         object
# dtype: object

# %%
print(df['horsepower'].unique())
# Out:
# ['130.0' '165.0' '150.0' '140.0' '198.0' '220.0' '215.0' '225.0' '190.0'
#  '170.0' '160.0' '95.00' '97.00' '85.00' '88.00' '46.00' '87.00' '90.00'
#  '113.0' '200.0' '210.0' '193.0' '?' '100.0' '105.0' '175.0' '153.0'
#  '180.0' '110.0' '72.00' '86.00' '70.00' '76.00' '65.00' '69.00' '60.00'
#  '80.00' '54.00' '208.0' '155.0' '112.0' '92.00' '145.0' '137.0' '158.0'
#  '167.0' '94.00' '107.0' '230.0' '49.00' '75.00' '91.00' '122.0' '67.00'
#  '83.00' '78.00' '52.00' '61.00' '93.00' '148.0' '129.0' '96.00' '71.00'
#  '98.00' '115.0' '53.00' '81.00' '79.00' '120.0' '152.0' '102.0' '108.0'
#  '68.00' '58.00' '149.0' '89.00' '63.00' '48.00' '66.00' '139.0' '103.0'
#  '125.0' '133.0' '138.0' '135.0' '142.0' '77.00' '62.00' '132.0' '84.00'
#  '64.00' '74.00' '116.0' '82.00']

# %% [markdown]
# **Data Columns**
# MPG - Numerical
# Cylinders - Numerical
# Displacemnt - Numerical
# Horsepower - Numerical   (Will need to fix)
# Weight - Numerical
# Accelartion - Numerical
# Model - Numerical
# Origin - Categorical
# Car Name - Text

# %% [markdown]
# There are no missing values in this dataset

# %% [markdown]
# Null = Weight does not affect MPG
# Alternative = Weight does affect MPG
# Two tailed as it could positively or negatively affect it.

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['horsepower'], df['acceleration'])
plt.title('Horsepower vs. Acceleration', fontsize=16)
plt.xlabel('Horsepower', fontsize=14)
plt.ylabel('Acceleration', fontsize=14)
plt.grid(True)
plt.show()

# %%
avg_mpg_by_origin = df.groupby('origin')['mpg'].mean()

plt.figure(figsize=(8, 6))
avg_mpg_by_origin.plot(kind='bar', color=['r', 'g', 'b'], alpha=0.7)
plt.title('Average Fuel Efficiency (mpg) by Country of Origin', fontsize=16)
plt.xlabel('Country of Origin', fontsize=14)
plt.ylabel('Average Fuel Efficiency (mpg)', fontsize=14)
plt.xticks(rotation=0)
plt.grid(True)
plt.show()

# %%
mpg_usa = df[df['origin'] == 1]['mpg'].tolist()
mpg_germany = df[df['origin'] == 2]['mpg'].tolist()
mpg_japan = df[df['origin'] == 3]['mpg'].tolist()

data = [mpg_usa, mpg_germany, mpg_japan]
labels = ['USA', 'Germany', 'Japan']

plt.figure(figsize=(8, 6))
plt.boxplot(data, labels=labels, patch_artist=True)
plt.title('Fuel Efficiency (mpg) vs. Country of Origin', fontsize=16)
plt.xlabel('Country of Origin', fontsize=14)
plt.ylabel('Fuel Efficiency (mpg)', fontsize=14)
plt.grid(True)
plt.show()

# %%
mpg_usa = df[df['origin'] == 1]['acceleration'].tolist()
mpg_germany = df[df['origin'] == 2]['acceleration'].tolist()
mpg_japan = df[df['origin'] == 3]['acceleration'].tolist()

data = [mpg_usa, mpg_germany, mpg_japan]
labels = ['USA', 'Germany', 'Japan']

plt.figure(figsize=(8, 6))
plt.boxplot(data, labels=labels, patch_artist=True)
plt.title('Acceleration vs. Country of Origin', fontsize=16)
plt.xlabel('Country of Origin', fontsize=14)
plt.ylabel('Acceleration', fontsize=14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
df[df['origin'] == 1]['cylinders'].hist(alpha=0.7, label='USA', bins=30)
df[df['origin'] == 2]['cylinders'].hist(alpha=0.7, label='Germany', bins=30)
df[df['origin'] == 3]['cylinders'].hist(alpha=0.7, label='Japan', bins=30)
plt.title('Distribution of Cylinders by Country of Origin', fontsize=16)
plt.xlabel('Number of Cylinders', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.legend()
plt.grid(True)
plt.show()
